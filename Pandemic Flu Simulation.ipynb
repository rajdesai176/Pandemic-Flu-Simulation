# %%
from scipy.stats import norm
import random
import time

# %%
peopleDictionary = []

# %% [markdown]
# ## Create a Person Class and define its Attributes

# %%
class Person():
    def __init__(self, startingImmunity):
        if random.randint(0,100)<startingImmunity:
            self.immunity = True
        else:
            self.immunity = False
        self.contagiousness = 0
        self.mask = False
        self.contagiousDays = 0
        
        # Use gaussian distribution for number of friends; average is 5 friends
        self.friends = int((norm.rvs(size=1,loc=0.5,scale=0.15)[0]*10).round(0))
        
    def wearMask(self):
        self.contagiousness *= 0.5
    
    def vaccine1(self):
        self.contagiousness *= 0.2
    
    def vaccine2(self):
        self.contagiousness *= 0.05

# %% [markdown]
# ## Take inputs for the simulation

# %%
def initiateSim():
    numPeople = int(input("Population: "))
    startingImmunity = int(input("Percentage of people with natural immunity: "))
    startingInfecters = int(input("How many people will be infectious at t=0: "))
    for x in range(0,numPeople):
        peopleDictionary.append(Person(startingImmunity))
    for x in range(0,startingInfecters):
        peopleDictionary[random.randint(0,len(peopleDictionary)-1)].contagiousness = int((norm.rvs(size=1,loc=0.5,scale=0.15)[0]*10).round(0)*10)
    daysContagious = int(input("How many days contagious: "))
    lockdownDay = int(input("Day for lockdown to be enforced: "))
    maskDay = int(input("Day for mask usage to be enforced: "))
    vaccine1Day = int(input("Day on which vaccine dose 1 provided: "))
    vaccine2Day = int(input("Day on which vaccine dose 2 provided: "))
    return daysContagious, lockdownDay, maskDay, vaccine1Day, vaccine2Day

# %% [markdown]
# ## Define Simulation Function

# %%
def runDay(daysContagious, lockdown):
    
    # This section simulates the spread, so it only operates on contagious people, thus:
    for person in [person for person in peopleDictionary if person.contagiousness>0 and person.friends>0]:
        peopleCouldMeetToday = int(person.friends)
        if peopleCouldMeetToday > 0:
            peopleMetToday = random.randint(0,peopleCouldMeetToday)
        else:
            peopleMetToday = 0
            
        if lockdown == True:
            peopleMetToday= random.randint(0,int(0.3*peopleCouldMeetToday))
            
        for x in range(0,peopleMetToday):
            friendInQuestion = peopleDictionary[random.randint(0,len(peopleDictionary)-1)]
            if random.randint(0,100)<person.contagiousness and friendInQuestion.contagiousness == 0 and friendInQuestion.immunity==False:
                friendInQuestion.contagiousness = int((norm.rvs(size=1,loc=0.5,scale=0.15)[0]*10).round(0)*10)
                
            
    for person in [person for person in peopleDictionary if person.contagiousness>0]:
        person.contagiousDays += 1
        if person.contagiousDays > daysContagious:
            person.immunity = True
            person.contagiousness = 0

# %% [markdown]
# ## Simulate and Collect the Output Data

# %%
lockdown = False
daysContagious, lockdownDay, maskDay, vaccine1Day, vaccine2Day = initiateSim()
saveFile = open("pandemicsave.txt", "a")
for a in range(0,100):
    for x in range(0,100):
        if x==lockdownDay:
            lockdown = True

        if x == maskDay:
            for person in peopleDictionary:
                person.wearMask()
                
        if x == vaccine1Day:
            for person in peopleDictionary:
                person.vaccine1()
                
        if x == vaccine2Day:
            for person in peopleDictionary:
                person.vaccine2()

        print("DAY ", x)
        runDay(daysContagious,lockdown)
        write = str(len([person for person in peopleDictionary if person.contagiousness>0])) + "\n" #to be saved in a dataframe to have 100 replications side by side
        saveFile.write(write)
        print(len([person for person in peopleDictionary if person.contagiousness>0]), " people are contagious on this day.")
    saveFile.close()  #file gets re-written and closed in every repliation hence only last replication data is retrieved.
# Out:
# Population: 500000
# Percentage of people with natural immunity: 15
# How many people will be infectious at t=0: 20
# How many days contagious: 7
# Day for lockdown to be enforced: 40
# Day for mask usage to be enforced: 20
# Day on which vaccine dose 1 provided: 100
# Day on which vaccine dose 2 provided: 100
# DAY  0
# 40  people are contagious on this day.
# DAY  1
# 58  people are contagious on this day.
# DAY  2
# 68  people are contagious on this day.
# DAY  3
# 90  people are contagious on this day.
# DAY  4
# 128  people are contagious on this day.
# DAY  5
# 171  people are contagious on this day.
# DAY  6
# 242  people are contagious on this day.
# DAY  7
# 307  people are contagious on this day.
# DAY  8
# 388  people are contagious on this day.
# DAY  9
# 482  people are contagious on this day.
# DAY  10
# 615  people are contagious on this day.
# DAY  11
# 778  people are contagious on this day.
# DAY  12
# 1020  people are contagious on this day.
# DAY  13
# 1317  people are contagious on this day.
# DAY  14
# 1678  people are contagious on this day.
# DAY  15
# 2147  people are contagious on this day.
# DAY  16
# 2745  people are contagious on this day.
# DAY  17
# 3534  people are contagious on this day.
# DAY  18
# 4514  people are contagious on this day.
# DAY  19
# 5793  people are contagious on this day.
# DAY  20
# 6440  people are contagious on this day.
# DAY  21
# 7251  people are contagious on this day.
# DAY  22
# 8401  people are contagious on this day.
# DAY  23
# 9808  people are contagious on this day.
# DAY  24
# 11598  people are contagious on this day.
# DAY  25
# 13870  people are contagious on this day.
# DAY  26
# 16784  people are contagious on this day.
# DAY  27
# 21408  people are contagious on this day.
# DAY  28
# 27355  people are contagious on this day.
# DAY  29
# 34658  people are contagious on this day.
# DAY  30
# 43970  people are contagious on this day.
# DAY  31
# 55525  people are contagious on this day.
# DAY  32
# 70022  people are contagious on this day.
# DAY  33
# 87911  people are contagious on this day.
# DAY  34
# 109553  people are contagious on this day.
# DAY  35
# 135118  people are contagious on this day.
# DAY  36
# 165077  people are contagious on this day.
# DAY  37
# 198748  people are contagious on this day.
# DAY  38
# 236009  people are contagious on this day.
# DAY  39
# 275164  people are contagious on this day.
# DAY  40
# 265426  people are contagious on this day.
# DAY  41
# 250206  people are contagious on this day.
# DAY  42
# 228825  people are contagious on this day.
# DAY  43
# 199926  people are contagious on this day.
# DAY  44
# 163510  people are contagious on this day.
# DAY  45
# 118994  people are contagious on this day.
# DAY  46
# 67059  people are contagious on this day.
# DAY  47
# 57262  people are contagious on this day.
# DAY  48
# 47565  people are contagious on this day.
# DAY  49
# 38219  people are contagious on this day.
# DAY  50
# 29743  people are contagious on this day.
# DAY  51
# 22274  people are contagious on this day.
# DAY  52
# 16128  people are contagious on this day.
# DAY  53
# 11582  people are contagious on this day.
# DAY  54
# 9221  people are contagious on this day.
# DAY  55
# 7225  people are contagious on this day.
# DAY  56
# 5458  people are contagious on this day.
# DAY  57
# 4084  people are contagious on this day.
# DAY  58
# 3054  people are contagious on this day.
# DAY  59
# 2280  people are contagious on this day.
# DAY  60
# 1754  people are contagious on this day.
# DAY  61
# 1362  people are contagious on this day.
# DAY  62
# 1035  people are contagious on this day.
# DAY  63
# 794  people are contagious on this day.
# DAY  64
# 598  people are contagious on this day.
# DAY  65
# 437  people are contagious on this day.
# DAY  66
# 343  people are contagious on this day.
# DAY  67
# 253  people are contagious on this day.
# DAY  68
# 187  people are contagious on this day.
# DAY  69
# 156  people are contagious on this day.
# DAY  70
# 126  people are contagious on this day.
# DAY  71
# 93  people are contagious on this day.
# DAY  72
# 74  people are contagious on this day.
# DAY  73
# 59  people are contagious on this day.
# DAY  74
# 50  people are contagious on this day.
# DAY  75
# 38  people are contagious on this day.
# DAY  76
# 28  people are contagious on this day.
# DAY  77
# 18  people are contagious on this day.
# DAY  78
# 16  people are contagious on this day.
# DAY  79
# 11  people are contagious on this day.
# DAY  80
# 5  people are contagious on this day.
# DAY  81
# 5  people are contagious on this day.
# DAY  82
# 4  people are contagious on this day.
# DAY  83
# 4  people are contagious on this day.
# DAY  84
# 4  people are contagious on this day.
# DAY  85
# 3  people are contagious on this day.
# DAY  86
# 3  people are contagious on this day.
# DAY  87
# 3  people are contagious on this day.
# DAY  88
# 2  people are contagious on this day.
# DAY  89
# 2  people are contagious on this day.
# DAY  90
# 1  people are contagious on this day.
# DAY  91
# 1  people are contagious on this day.
# DAY  92
# 0  people are contagious on this day.
# DAY  93
# 0  people are contagious on this day.
# DAY  94
# 0  people are contagious on this day.
# DAY  95
# 0  people are contagious on this day.
# DAY  96
# 0  people are contagious on this day.
# DAY  97
# 0  people are contagious on this day.
# DAY  98
# 0  people are contagious on this day.
# DAY  99
# 0  people are contagious on this day.
# DAY  0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-0c7bbc99b237> in <module>
#      22         runDay(daysContagious,lockdown)
#      23         write = str(len([person for person in peopleDictionary if person.contagiousness>0])) + "\n" #to be saved in a dataframe to have 100 replications side by side
# ---> 24         saveFile.write(write)
#      25         print(len([person for person in peopleDictionary if person.contagiousness>0]), " people are contagious on this day.")
#      26     saveFile.close()  #file gets re-written and closed in every repliation hence only last replication data is retrieved.
#
# ValueError: I/O operation on closed file.
